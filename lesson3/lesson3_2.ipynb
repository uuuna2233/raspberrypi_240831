# %%
total = 0
total += 1
total += 2
total += 3
total += 4
total += 5
total += 6
total += 7
total += 8
total += 9
total += 10
total
# Out:
# 55

# %%
total = 0
for i in range(1,101):
    total += i

total
# Out:
# 5050

# %%
for i in 'robot':
    print(i)
# Out:
# r
# o
# b
# o
# t

# %%
import requests

r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926831294","type":"DeleteEvent","actor":{"id":26026535,"login":"provokateurin","display_login":"provokateurin","gravatar_id":"","url":"https://api.github.com/users/provokateurin","avatar_url":"https://avatars.githubusercontent.com/u/26026535?"},"repo":{"id":446889217,"name":"nextcloud/neon","url":"https://api.github.com/repos/nextcloud/neon"},"payload":{"ref":"fix/account_repository/login-active-account","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2024-09-14T07:51:26Z","org":{"id":19211038,"login":"nextcloud","gravatar_id":"","url":"https://api.github.com/orgs/nextcloud","avatar_url":"https://avatars.githubusercontent.com/u/19211038?"}},{"id":"41926831287","type":"PushEvent","actor":{"id":161940393,"login":"HKiet-dev","display_login":"HKiet-dev","gravatar_id":"","url":"https://api.github.com/users/HKiet-dev","avatar_url":"https://avatars.githubusercontent.com/u/161940393?"},"repo":{"id":843680280,"name":"HKiet-dev/G4U","url":"https://api.github.co
# ...
